# %%
import pymongo
from string import punctuation

# %%
client = pymongo.MongoClient('localhost',27017)
wuhan = client['wuhan']
ershoufang = wuhan['ershoufang']

# %%
for i in ershoufang.find().limit(300):
    print(i['position'].split())
# Out:
# ['中楼层(共17层)', '2012年建板楼', '-', '金银湖']
# ['高楼层(共6层)', '2000年建塔楼', '-', '龙阳大道']
# ['中楼层(共22层)', '2007年建塔楼', '-', '螃蟹甲']
# ['中楼层(共5层)', '2000年建板楼', '-', '中南丁字桥']
# ['高楼层(共28层)', '2005年建塔楼', '-', '积玉桥']
# ['高楼层(共23层)', '2003年建板楼', '-', '徐家棚']
# ['低楼层(共6层)', '2005年建板楼', '-', '珞狮南路']
# ['低楼层(共18层)', '2006年建板楼', '-', '三阳路']
# ['中楼层(共18层)', '2005年建板塔结合', '-', '老南湖']
# ['低楼层(共22层)', '2009年建板楼', '-', '武昌火车站']
# ['中楼层(共6层)', '2003年建板楼', '-', '老南湖']
# ['高楼层(共6层)', '2003年建板楼', '-', '鹦鹉大道']
# ['中楼层(共32层)', '2011年建板楼', '-', '三阳路']
# ['高楼层(共7层)', '塔楼', '-', '中南丁字桥']
# ['高楼层(共18层)', '2007年建塔楼', '-', '珞狮南路']
# ['高楼层(共7层)', '板楼', '-', '首义']
# ['低楼层(共30层)', '2005年建塔楼', '-', '螃蟹甲']
# ['高楼层(共11层)', '2008年建板塔结合', '-', '中北路']
# ['低楼层(共8层)', '2000年建塔楼', '-', '冶金']
# ['低楼层(共16层)', '2008年建板楼', '-', '新南湖']
# ['中楼层(共32层)', '2010年建板楼', '-', '珞狮南路']
# ['中楼层(共33层)', '2012年建板楼', '-', '三阳路']
# ['中楼层(共31层)', '2005年建板楼', '-', '武广万松园']
# ['中楼层(共6层)', '2004年建板楼', '-', '新南湖']
# ['中楼层(共11层)', '2001年建塔楼', '-', '古田']
# ...
